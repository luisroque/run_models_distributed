# %%
import pickle
import os
from collections import Iterable
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set()
plt.rcParams.update({'font.size': 22})
# Out:
# <ipython-input-9-f22033fd6734>:3: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#   from collections import Iterable

# %%
def flatten(lis):
     for item in lis:
        if isinstance(item, Iterable) and not isinstance(item, str):
            for x in flatten(item):
                yield x
        else:        
            yield item
            
def find(lst, s):
    return [i for i, x in enumerate(lst) if x==s]

def keys_exists(element, *keys):
    '''
    Check if *keys (nested) exists in `element` (dict).
    '''
    if not isinstance(element, dict):
        raise AttributeError('keys_exists() expects dict as first argument.')
    if len(keys) == 0:
        raise AttributeError('keys_exists() expects at least two arguments, one given.')

    _element = element
    for key in keys:
        try:
            _element = _element[key]
        except KeyError:
            return False
    return True

# %%
dataset = 'prison'

# %%
with open('../results/results_gp_cov_tourism_mint_magnitude_warp_v1_s1.pickle', 'rb') as handle:
    f = pickle.load(handle)

# %%
f
# Out:
# {'mase': {'bottom': 1.095,
#   'total': 0.917,
#   'state': 0.904,
#   'zone': 1.083,
#   'region': 0.972,
#   'purpose': 0.923,
#   'all': 1.092},
#  'rmse': {'bottom': 68.535,
#   'total': 2445.295,
#   'state': 661.688,
#   'zone': 325.858,
#   'region': 164.128,
#   'purpose': 1053.445,
#   'all': 106.994}}

# %%
os.listdir('../results')
# Out:
# ['results_gp_cov_police_deepar_jitter_v0_s7.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v1_s1.pickle',
#  'results_gp_cov_prison_gpf_jitter_v0_s4.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v4_s2.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v1_s7.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v3_s6.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v0_s0.pickle',
#  'results_gp_cov_tourism_mint_scaling_v5_s5.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v2_s8.pickle',
#  'results_gp_cov_m5_gpf_jitter_v4_s0.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v5_s7.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v3_s3.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v3_s8.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v5_s5.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v4_s3.pickle',
#  'results_gp_cov_prison_mint_time_warp_v0_s0.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v0_s1.pickle',
#  'results_gp_cov_police_deepar_time_warp_v0_s0.pickle',
#  'results_gp_cov_prison_deepar_jitter_v5_s8.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v5_s7.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v0_s5.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v3_s4.pickle',
#  'results_gp_cov_prison_deepar_jitter_v3_s6.pickle',
#  'results_gp_cov_police_deepar_scaling_v3_s6.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v1_s1.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v5_s3.pickle',
#  'results_gp_cov_prison_mint_time_warp_v5_s9.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_orig_s0.pickle',
#  'results_gp_cov_police_deepar_jitter_v0_s1.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v4_s6.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v2_s9.pickle',
#  'results_gp_cov_police_deepar_time_warp_v0_s5.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v2_s5.pickle',
#  'results_gp_cov_police_mint_jitter_v1_s1.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v2_s7.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v0_s3.pickle',
#  'results_gp_cov_police_deepar_time_warp_v5_s7.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v4_s8.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v2_s5.pickle',
#  'results_gp_cov_prison_deepar_scaling_v1_s5.pickle',
#  'results_gp_cov_m5_deepar_jitter_v5_s6.pickle',
#  'results_gp_cov_m5_mint_jitter_v5_s8.pickle',
#  'results_gp_cov_police_gpf_jitter_orig_s0.pickle',
#  'results_gp_cov_police_gpf_scaling_v1_s1.pickle',
#  'results_gp_cov_prison_gpf_jitter_v0_s5.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v2_s5.pickle',
#  'results_gp_cov_prison_mint_scaling_v0_s0.pickle',
#  'results_gp_cov_m5_gpf_jitter_v4_s8.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v3_s7.pickle',
#  'results_gp_cov_police_deepar_time_warp_v3_s0.pickle',
#  'results_gp_cov_m5_mint_scaling_v1_s9.pickle',
#  'results_gp_cov_m5_deepar_jitter_v4_s1.pickle',
#  'results_gp_cov_police_gpf_scaling_v0_s0.pickle',
#  'results_gp_cov_prison_deepar_scaling_v4_s5.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v2_s3.pickle',
#  'results_gp_cov_police_deepar_time_warp_v1_s0.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v4_s6.pickle',
#  'results_gp_cov_police_deepar_scaling_v5_s6.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v2_s3.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v1_s8.pickle',
#  'results_gp_cov_m5_mint_time_warp_v5_s0.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v1_s9.pickle',
#  'results_gp_cov_m5_deepar_scaling_v1_s4.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v3_s9.pickle',
#  'results_gp_cov_prison_deepar_jitter_v4_s5.pickle',
#  'results_gp_cov_police_deepar_scaling_v2_s7.pickle',
#  'results_gp_cov_tourism_mint_jitter_v2_s3.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v0_s1.pickle',
#  'results_gp_cov_police_deepar_scaling_v5_s5.pickle',
#  'results_gp_cov_m5_mint_jitter_v4_s4.pickle',
#  'results_gp_cov_prison_deepar_jitter_v2_s7.pickle',
#  'results_gp_cov_m5_gpf_jitter_v1_s6.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v1_s5.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v3_s5.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v3_s7.pickle',
#  'results_gp_cov_police_gpf_jitter_v1_s7.pickle',
#  'results_gp_cov_police_deepar_jitter_v2_s7.pickle',
#  'results_gp_cov_police_gpf_time_warp_v0_s2.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v2_s3.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v1_s4.pickle',
#  'results_gp_cov_prison_deepar_jitter_v0_s2.pickle',
#  'results_gp_cov_police_gpf_time_warp_v0_s0.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v0_s9.pickle',
#  'results_gp_cov_m5_gpf_scaling_v0_s4.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v0_s6.pickle',
#  'results_gp_cov_m5_gpf_jitter_v4_s3.pickle',
#  'results_gp_cov_prison_gpf_jitter_v3_s3.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v4_s1.pickle',
#  'results_gp_cov_police_deepar_time_warp_orig_s0.pickle',
#  'results_gp_cov_m5_gpf_jitter_v2_s6.pickle',
#  'results_gp_cov_m5_mint_scaling_v3_s9.pickle',
#  'results_gp_cov_prison_deepar_scaling_v0_s8.pickle',
#  'results_gp_cov_prison_gpf_scaling_v0_s0.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v5_s8.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v0_s1.pickle',
#  'results_gp_cov_police_mint_jitter_v0_s2.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v3_s8.pickle',
#  'results_gp_cov_m5_gpf_jitter_v3_s8.pickle',
#  'results_gp_cov_tourism_mint_scaling_v0_s9.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v5_s8.pickle',
#  'results_gp_cov_tourism_mint_jitter_v2_s0.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v4_s9.pickle',
#  'results_gp_cov_prison_gpf_jitter_v1_s5.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v3_s2.pickle',
#  'results_gp_cov_prison_deepar_scaling_v5_s6.pickle',
#  'results_gp_cov_prison_mint_time_warp_v4_s8.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v2_s1.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v1_s5.pickle',
#  'results_gp_cov_m5_deepar_jitter_v4_s9.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v1_s3.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v1_s5.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v5_s1.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v0_s7.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v1_s0.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v5_s5.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v2_s7.pickle',
#  'results_gp_cov_prison_deepar_scaling_v4_s2.pickle',
#  'results_gp_cov_m5_mint_time_warp_v0_s8.pickle',
#  'results_gp_cov_m5_mint_time_warp_v4_s9.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v5_s2.pickle',
#  'results_gp_cov_police_deepar_time_warp_v5_s1.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v1_s1.pickle',
#  'results_gp_cov_prison_deepar_scaling_v0_s9.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v0_s4.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v5_s4.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v1_s0.pickle',
#  'results_gp_cov_prison_mint_jitter_v2_s6.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v0_s0.pickle',
#  'results_gp_cov_prison_mint_time_warp_v4_s2.pickle',
#  'results_gp_cov_prison_gpf_scaling_v1_s4.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v3_s2.pickle',
#  'results_gp_cov_police_deepar_jitter_v5_s7.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v4_s6.pickle',
#  'results_gp_cov_police_deepar_time_warp_v0_s7.pickle',
#  'results_gp_cov_police_deepar_time_warp_v4_s2.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v4_s3.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v2_s8.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v2_s2.pickle',
#  'results_gp_cov_prison_gpf_scaling_v2_s2.pickle',
#  'results_gp_cov_prison_mint_time_warp_v4_s0.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v0_s5.pickle',
#  'results_gp_cov_prison_gpf_jitter_v1_s1.pickle',
#  'results_gp_cov_police_mint_jitter_v2_s5.pickle',
#  'results_gp_cov_m5_mint_jitter_v3_s9.pickle',
#  'results_gp_cov_police_deepar_scaling_v1_s9.pickle',
#  'results_gp_cov_prison_gpf_scaling_v2_s9.pickle',
#  'results_gp_cov_police_mint_jitter_v2_s0.pickle',
#  'results_gp_cov_police_deepar_scaling_v4_s2.pickle',
#  'results_gp_cov_prison_gpf_jitter_v0_s2.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v1_s5.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v3_s9.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v1_s4.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v0_s6.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v1_s9.pickle',
#  'results_gp_cov_m5_gpf_jitter_v5_s6.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v1_s9.pickle',
#  'results_gp_cov_m5_deepar_jitter_v0_s1.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v0_s0.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v1_s8.pickle',
#  'results_gp_cov_prison_mint_time_warp_v5_s1.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v0_s5.pickle',
#  'results_gp_cov_prison_mint_jitter_v0_s3.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v4_s7.pickle',
#  'results_gp_cov_prison_deepar_scaling_v5_s7.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v5_s7.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v4_s7.pickle',
#  'results_gp_cov_prison_gpf_jitter_v5_s3.pickle',
#  'results_gp_cov_police_gpf_jitter_v0_s5.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v0_s3.pickle',
#  'results_gp_cov_prison_mint_scaling_v1_s1.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v5_s1.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v2_s6.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v5_s0.pickle',
#  'results_gp_cov_m5_deepar_time_warp_orig_s0.pickle',
#  'results_gp_cov_tourism_gpf_time_warp_v0_s0.pickle',
#  'results_gp_cov_m5_mint_scaling_v3_s4.pickle',
#  'results_gp_cov_police_gpf_jitter_v0_s0.pickle',
#  'results_gp_cov_m5_mint_time_warp_v5_s3.pickle',
#  'results_gp_cov_police_deepar_jitter_v3_s5.pickle',
#  'results_gp_cov_prison_deepar_scaling_v2_s8.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v1_s0.pickle',
#  'results_gp_cov_police_deepar_scaling_v3_s3.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v1_s6.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v3_s1.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v5_s9.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v5_s2.pickle',
#  'results_gp_cov_m5_mint_scaling_v2_s2.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v2_s6.pickle',
#  'results_gp_cov_m5_gpf_jitter_v2_s8.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v2_s8.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v2_s2.pickle',
#  'results_gp_cov_prison_gpf_jitter_v1_s0.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v0_s5.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v4_s5.pickle',
#  'results_gp_cov_prison_deepar_jitter_v1_s9.pickle',
#  'results_gp_cov_prison_mint_jitter_v3_s3.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v4_s8.pickle',
#  'results_gp_cov_prison_gpf_jitter_v5_s9.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v3_s2.pickle',
#  'results_gp_cov_prison_mint_scaling_v0_s5.pickle',
#  'results_gp_cov_prison_mint_jitter_v3_s7.pickle',
#  'results_gp_cov_prison_mint_time_warp_v3_s2.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v5_s1.pickle',
#  'results_gp_cov_tourism_mint_jitter_v1_s5.pickle',
#  'results_gp_cov_tourism_gpf_time_warp_v1_s8.pickle',
#  'results_gp_cov_prison_deepar_scaling_v2_s6.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v3_s5.pickle',
#  'results_gp_cov_prison_mint_scaling_v2_s2.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v1_s6.pickle',
#  'results_gp_cov_m5_deepar_scaling_v1_s2.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v5_s6.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v5_s5.pickle',
#  'results_gp_cov_m5_gpf_jitter_v2_s1.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v5_s0.pickle',
#  'results_gp_cov_police_gpf_scaling_v0_s4.pickle',
#  'results_gp_cov_prison_gpf_jitter_v4_s5.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v5_s7.pickle',
#  'results_gp_cov_m5_gpf_jitter_v3_s4.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v5_s0.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v2_s2.pickle',
#  'results_gp_cov_m5_deepar_jitter_v1_s7.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v1_s0.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v4_s8.pickle',
#  'results_gp_cov_m5_deepar_jitter_v3_s2.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v0_s4.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v2_s3.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v0_s4.pickle',
#  'results_gp_cov_m5_gpf_jitter_v2_s5.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v5_s8.pickle',
#  'results_gp_cov_m5_deepar_scaling_v1_s6.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v2_s3.pickle',
#  'results_gp_cov_prison_mint_scaling_v4_s3.pickle',
#  'results_gp_cov_prison_gpf_scaling_v5_s1.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v2_s9.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v2_s9.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v2_s2.pickle',
#  'results_gp_cov_police_deepar_jitter_v1_s5.pickle',
#  'results_gp_cov_m5_mint_jitter_v4_s7.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v0_s2.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v1_s2.pickle',
#  'results_gp_cov_m5_deepar_jitter_v4_s5.pickle',
#  'results_gp_cov_prison_gpf_scaling_v3_s5.pickle',
#  'results_gp_cov_m5_mint_jitter_v0_s7.pickle',
#  'results_gp_cov_m5_deepar_scaling_v2_s5.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v4_s1.pickle',
#  'results_gp_cov_m5_gpf_jitter_v1_s2.pickle',
#  'results_gp_cov_tourism_mint_jitter_v0_s6.pickle',
#  'results_gp_cov_tourism_gpf_jitter_orig_s0.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v3_s6.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v4_s8.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v3_s7.pickle',
#  'results_gp_cov_prison_mint_time_warp_v3_s0.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v1_s5.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v1_s8.pickle',
#  'results_gp_cov_prison_deepar_jitter_v4_s4.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v3_s8.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v1_s4.pickle',
#  'results_gp_cov_police_deepar_scaling_v3_s4.pickle',
#  'results_gp_cov_police_deepar_time_warp_v3_s8.pickle',
#  'results_gp_cov_m5_gpf_jitter_v1_s0.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v3_s9.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v0_s7.pickle',
#  'results_gp_cov_m5_mint_scaling_v1_s8.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v4_s6.pickle',
#  'results_gp_cov_m5_mint_scaling_v2_s1.pickle',
#  'results_gp_cov_tourism_mint_scaling_v3_s9.pickle',
#  'results_gp_cov_tourism_mint_jitter_orig_s0.pickle',
#  'results_gp_cov_m5_deepar_scaling_v3_s7.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v4_s3.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v1_s9.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v5_s3.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v1_s6.pickle',
#  'results_gp_cov_prison_deepar_scaling_v4_s4.pickle',
#  'results_gp_cov_prison_mint_scaling_v0_s6.pickle',
#  'results_gp_cov_prison_mint_scaling_v0_s8.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v0_s2.pickle',
#  'results_gp_cov_m5_deepar_scaling_v0_s6.pickle',
#  'results_gp_cov_m5_mint_jitter_v3_s7.pickle',
#  'results_gp_cov_m5_deepar_scaling_v3_s5.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v5_s7.pickle',
#  'results_gp_cov_police_mint_jitter_v1_s0.pickle',
#  'results_gp_cov_m5_mint_jitter_v4_s3.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v3_s2.pickle',
#  'results_gp_cov_prison_mint_time_warp_v2_s4.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v2_s0.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v4_s0.pickle',
#  'results_gp_cov_m5_deepar_scaling_v4_s3.pickle',
#  'results_gp_cov_prison_gpf_jitter_v0_s9.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v3_s9.pickle',
#  'results_gp_cov_m5_mint_time_warp_v4_s8.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v1_s2.pickle',
#  'results_gp_cov_prison_mint_jitter_v5_s5.pickle',
#  'results_gp_cov_police_mint_jitter_v2_s7.pickle',
#  'results_gp_cov_tourism_mint_jitter_v0_s2.pickle',
#  'results_gp_cov_prison_mint_scaling_v3_s2.pickle',
#  'results_gp_cov_prison_mint_jitter_v3_s2.pickle',
#  'results_gp_cov_police_deepar_jitter_v5_s6.pickle',
#  'results_gp_cov_tourism_mint_scaling_v3_s8.pickle',
#  'results_gp_cov_police_mint_time_warp_orig_s0.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v3_s2.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v1_s5.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v1_s0.pickle',
#  'results_gp_cov_tourism_mint_scaling_v5_s7.pickle',
#  'results_gp_cov_prison_gpf_scaling_v3_s3.pickle',
#  'results_gp_cov_police_deepar_time_warp_v0_s6.pickle',
#  'results_gp_cov_police_deepar_jitter_v1_s0.pickle',
#  'results_gp_cov_m5_deepar_scaling_v5_s7.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v1_s0.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v5_s2.pickle',
#  'results_gp_cov_tourism_mint_time_warp_orig_s0.pickle',
#  'results_gp_cov_police_deepar_time_warp_v4_s7.pickle',
#  'results_gp_cov_prison_gpf_scaling_v2_s1.pickle',
#  'results_gp_cov_prison_mint_jitter_v2_s3.pickle',
#  'results_gp_cov_tourism_mint_scaling_v5_s8.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v4_s1.pickle',
#  'results_gp_cov_prison_gpf_jitter_v4_s7.pickle',
#  'results_gp_cov_m5_gpf_jitter_v1_s3.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v0_s9.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v3_s8.pickle',
#  'results_gp_cov_police_deepar_scaling_v2_s3.pickle',
#  'results_gp_cov_prison_mint_jitter_v2_s9.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v5_s5.pickle',
#  'results_gp_cov_police_deepar_scaling_v1_s1.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v4_s7.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v3_s6.pickle',
#  'results_gp_cov_prison_deepar_scaling_v0_s5.pickle',
#  'results_gp_cov_m5_deepar_scaling_v2_s8.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v5_s7.pickle',
#  'results_gp_cov_prison_gpf_scaling_v3_s0.pickle',
#  'results_gp_cov_prison_mint_scaling_v2_s8.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v4_s6.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v2_s0.pickle',
#  'results_gp_cov_prison_deepar_jitter_v3_s1.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v1_s3.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v1_s5.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v1_s8.pickle',
#  'results_gp_cov_prison_mint_time_warp_v5_s6.pickle',
#  'results_gp_cov_prison_mint_jitter_v1_s2.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v5_s9.pickle',
#  'results_gp_cov_police_deepar_scaling_v4_s8.pickle',
#  'results_gp_cov_prison_deepar_jitter_v2_s3.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v0_s0.pickle',
#  'results_gp_cov_police_gpf_time_warp_v0_s5.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v4_s2.pickle',
#  'results_gp_cov_m5_deepar_scaling_v3_s1.pickle',
#  'results_gp_cov_police_deepar_scaling_v0_s0.pickle',
#  'results_gp_cov_m5_deepar_scaling_v0_s5.pickle',
#  'results_gp_cov_tourism_mint_jitter_v0_s7.pickle',
#  'results_gp_cov_police_deepar_jitter_v4_s0.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v0_s0.pickle',
#  'results_gp_cov_prison_mint_time_warp_v5_s2.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v0_s3.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v1_s7.pickle',
#  'results_gp_cov_police_gpf_scaling_v0_s2.pickle',
#  'results_gp_cov_police_mint_jitter_v0_s3.pickle',
#  'results_gp_cov_police_deepar_scaling_v4_s5.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v3_s2.pickle',
#  'results_gp_cov_prison_mint_scaling_v1_s0.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v2_s5.pickle',
#  'results_gp_cov_police_deepar_jitter_v1_s4.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v2_s6.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v3_s7.pickle',
#  'results_gp_cov_police_deepar_jitter_v4_s1.pickle',
#  'results_gp_cov_police_mint_jitter_v0_s5.pickle',
#  'results_gp_cov_m5_deepar_jitter_v1_s9.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v5_s3.pickle',
#  'results_gp_cov_prison_gpf_jitter_v0_s6.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v0_s0.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v4_s9.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v3_s3.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v5_s7.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v2_s1.pickle',
#  'results_gp_cov_prison_deepar_scaling_orig_s0.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v2_s3.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v4_s4.pickle',
#  'results_gp_cov_police_deepar_scaling_v4_s3.pickle',
#  'results_gp_cov_tourism_mint_jitter_v5_s7.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v2_s5.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v0_s6.pickle',
#  'results_gp_cov_prison_gpf_jitter_v2_s1.pickle',
#  'results_gp_cov_prison_gpf_jitter_v1_s3.pickle',
#  'results_gp_cov_police_mint_jitter_v0_s9.pickle',
#  'results_gp_cov_m5_deepar_scaling_v2_s3.pickle',
#  'results_gp_cov_prison_deepar_jitter_v1_s2.pickle',
#  'results_gp_cov_tourism_mint_scaling_v3_s7.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v0_s0.pickle',
#  'results_gp_cov_police_gpf_time_warp_v0_s3.pickle',
#  'results_gp_cov_tourism_mint_jitter_v4_s5.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v4_s9.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v4_s2.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_orig_s0.pickle',
#  'results_gp_cov_prison_mint_time_warp_v3_s6.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v2_s6.pickle',
#  'results_gp_cov_police_deepar_jitter_v1_s8.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v3_s6.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v3_s1.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v3_s7.pickle',
#  'results_gp_cov_police_deepar_jitter_v1_s2.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v3_s5.pickle',
#  'results_gp_cov_m5_gpf_jitter_v0_s1.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v4_s5.pickle',
#  'results_gp_cov_m5_gpf_scaling_v0_s2.pickle',
#  'results_gp_cov_prison_gpf_scaling_v1_s9.pickle',
#  'results_gp_cov_prison_mint_jitter_orig_s0.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v0_s9.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v0_s5.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v0_s5.pickle',
#  'results_gp_cov_tourism_mint_scaling_v2_s6.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v3_s4.pickle',
#  'results_gp_cov_prison_mint_jitter_v5_s8.pickle',
#  'results_gp_cov_m5_mint_time_warp_v5_s1.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v3_s1.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v0_s0.pickle',
#  'results_gp_cov_prison_mint_jitter_v3_s0.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v2_s7.pickle',
#  'results_gp_cov_tourism_mint_scaling_v4_s9.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v4_s5.pickle',
#  'results_gp_cov_tourism_mint_scaling_v4_s0.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v5_s6.pickle',
#  'results_gp_cov_tourism_mint_scaling_v0_s5.pickle',
#  'results_gp_cov_prison_mint_time_warp_v4_s3.pickle',
#  'results_gp_cov_m5_mint_jitter_v4_s2.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v5_s3.pickle',
#  'results_gp_cov_police_deepar_jitter_v0_s4.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v0_s4.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v1_s9.pickle',
#  'results_gp_cov_police_mint_jitter_v3_s6.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v3_s8.pickle',
#  'results_gp_cov_police_gpf_jitter_v1_s8.pickle',
#  'results_gp_cov_police_deepar_jitter_v2_s1.pickle',
#  'results_gp_cov_police_deepar_jitter_v0_s3.pickle',
#  'results_gp_cov_prison_mint_scaling_v1_s8.pickle',
#  'results_gp_cov_tourism_mint_scaling_v4_s3.pickle',
#  'results_gp_cov_m5_gpf_jitter_v2_s0.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v5_s1.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v5_s5.pickle',
#  'results_gp_cov_m5_mint_jitter_v5_s6.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v4_s0.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v4_s0.pickle',
#  'results_gp_cov_m5_mint_time_warp_v2_s8.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v4_s0.pickle',
#  'results_gp_cov_prison_mint_time_warp_v3_s7.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v5_s5.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v0_s9.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v5_s8.pickle',
#  'results_gp_cov_prison_deepar_jitter_v1_s4.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v4_s6.pickle',
#  'results_gp_cov_police_deepar_time_warp_v2_s8.pickle',
#  'results_gp_cov_m5_mint_time_warp_orig_s0.pickle',
#  'results_gp_cov_m5_deepar_scaling_v5_s5.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v0_s3.pickle',
#  'results_gp_cov_prison_mint_scaling_v3_s5.pickle',
#  'results_gp_cov_prison_mint_time_warp_v3_s3.pickle',
#  'results_gp_cov_m5_gpf_jitter_v2_s3.pickle',
#  'results_gp_cov_m5_deepar_scaling_v0_s9.pickle',
#  'results_gp_cov_prison_mint_scaling_v3_s6.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v1_s6.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v2_s9.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v2_s6.pickle',
#  'results_gp_cov_m5_deepar_jitter_v3_s6.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v1_s0.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v5_s6.pickle',
#  'results_gp_cov_tourism_gpf_time_warp_v1_s3.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v3_s8.pickle',
#  'results_gp_cov_m5_mint_jitter_v0_s5.pickle',
#  'results_gp_cov_m5_deepar_jitter_v1_s2.pickle',
#  'results_gp_cov_m5_gpf_scaling_orig_s0.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v4_s8.pickle',
#  'results_gp_cov_prison_mint_scaling_v4_s5.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v3_s3.pickle',
#  'results_gp_cov_prison_mint_scaling_v3_s9.pickle',
#  'results_gp_cov_m5_deepar_jitter_v0_s5.pickle',
#  'results_gp_cov_prison_mint_time_warp_v5_s4.pickle',
#  'results_gp_cov_prison_deepar_scaling_v4_s9.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v2_s0.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v3_s3.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v4_s7.pickle',
#  'results_gp_cov_tourism_mint_jitter_v3_s1.pickle',
#  'results_gp_cov_tourism_mint_scaling_v1_s2.pickle',
#  'results_gp_cov_police_deepar_scaling_v4_s6.pickle',
#  'results_gp_cov_tourism_gpf_time_warp_v1_s0.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v5_s3.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v4_s6.pickle',
#  'results_gp_cov_police_deepar_jitter_v0_s5.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v5_s1.pickle',
#  'results_gp_cov_m5_mint_time_warp_v4_s1.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v0_s6.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v5_s4.pickle',
#  'results_gp_cov_m5_deepar_jitter_v0_s4.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v4_s5.pickle',
#  'results_gp_cov_tourism_mint_jitter_v4_s0.pickle',
#  'results_gp_cov_prison_deepar_scaling_v0_s3.pickle',
#  'results_gp_cov_tourism_mint_scaling_v1_s1.pickle',
#  'results_gp_cov_police_mint_jitter_v1_s5.pickle',
#  'results_gp_cov_police_deepar_jitter_v3_s3.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v1_s8.pickle',
#  'results_gp_cov_m5_mint_time_warp_v3_s5.pickle',
#  'results_gp_cov_prison_deepar_jitter_v2_s8.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v2_s6.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v3_s9.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v0_s0.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v3_s5.pickle',
#  'results_gp_cov_tourism_mint_jitter_v2_s6.pickle',
#  'results_gp_cov_prison_mint_time_warp_v4_s4.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v0_s8.pickle',
#  'results_gp_cov_prison_deepar_scaling_v4_s3.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v0_s2.pickle',
#  'results_gp_cov_tourism_gpf_time_warp_v2_s6.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v2_s1.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v1_s3.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v5_s7.pickle',
#  'results_gp_cov_prison_mint_time_warp_v5_s3.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v5_s5.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v3_s0.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v0_s5.pickle',
#  'results_gp_cov_police_deepar_time_warp_v2_s7.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v5_s8.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v0_s8.pickle',
#  'results_gp_cov_prison_gpf_jitter_v4_s2.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v5_s9.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v1_s4.pickle',
#  'results_gp_cov_m5_mint_time_warp_v1_s5.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v2_s7.pickle',
#  'results_gp_cov_tourism_mint_jitter_v0_s8.pickle',
#  'results_gp_cov_police_deepar_scaling_v1_s6.pickle',
#  'results_gp_cov_prison_mint_scaling_v1_s6.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v4_s6.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v3_s1.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v2_s9.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v4_s0.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v4_s1.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v1_s2.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v1_s8.pickle',
#  'results_gp_cov_tourism_mint_scaling_v4_s8.pickle',
#  'results_gp_cov_m5_mint_jitter_v1_s1.pickle',
#  'results_gp_cov_m5_deepar_scaling_v4_s7.pickle',
#  'results_gp_cov_tourism_mint_jitter_v4_s9.pickle',
#  'results_gp_cov_prison_gpf_scaling_v2_s4.pickle',
#  'results_gp_cov_m5_deepar_scaling_v1_s0.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v5_s9.pickle',
#  'results_gp_cov_police_gpf_jitter_v0_s8.pickle',
#  'results_gp_cov_prison_gpf_jitter_v5_s8.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v3_s9.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v2_s4.pickle',
#  'results_gp_cov_tourism_mint_scaling_v2_s0.pickle',
#  'results_gp_cov_m5_mint_jitter_v3_s5.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v5_s2.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v5_s4.pickle',
#  'results_gp_cov_prison_deepar_jitter_v0_s0.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v3_s8.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v0_s9.pickle',
#  'results_gp_cov_police_deepar_scaling_v0_s8.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v1_s2.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v1_s7.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v0_s3.pickle',
#  'results_gp_cov_m5_mint_scaling_v5_s3.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v5_s5.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v4_s6.pickle',
#  'results_gp_cov_prison_mint_time_warp_v2_s6.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v4_s9.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v0_s9.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v4_s8.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v0_s2.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v5_s6.pickle',
#  'results_gp_cov_prison_deepar_jitter_v1_s7.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v3_s7.pickle',
#  'results_gp_cov_police_deepar_time_warp_v1_s6.pickle',
#  'results_gp_cov_tourism_mint_scaling_v0_s0.pickle',
#  'results_gp_cov_m5_gpf_jitter_v1_s8.pickle',
#  'results_gp_cov_prison_mint_jitter_v5_s3.pickle',
#  'results_gp_cov_prison_deepar_jitter_v5_s0.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v4_s6.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v5_s9.pickle',
#  'results_gp_cov_prison_mint_time_warp_v3_s1.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v4_s2.pickle',
#  'results_gp_cov_police_deepar_time_warp_v5_s3.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v0_s5.pickle',
#  'results_gp_cov_police_deepar_scaling_v5_s0.pickle',
#  'results_gp_cov_prison_gpf_scaling_v4_s9.pickle',
#  'results_gp_cov_tourism_mint_scaling_v0_s6.pickle',
#  'results_gp_cov_m5_gpf_jitter_v4_s7.pickle',
#  'results_gp_cov_prison_deepar_scaling_v0_s2.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v4_s3.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v2_s1.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v4_s6.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v5_s8.pickle',
#  'results_gp_cov_m5_gpf_jitter_v3_s2.pickle',
#  'results_gp_cov_m5_deepar_scaling_v2_s4.pickle',
#  'results_gp_cov_prison_deepar_jitter_v1_s1.pickle',
#  'results_gp_cov_prison_mint_jitter_v2_s4.pickle',
#  'results_gp_cov_prison_gpf_jitter_v4_s0.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v3_s5.pickle',
#  'results_gp_cov_prison_mint_time_warp_v2_s3.pickle',
#  'results_gp_cov_prison_mint_jitter_v4_s1.pickle',
#  'results_gp_cov_police_mint_jitter_v0_s6.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v3_s6.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v0_s6.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v5_s6.pickle',
#  'results_gp_cov_m5_deepar_jitter_v1_s5.pickle',
#  'results_gp_cov_prison_mint_jitter_v0_s4.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v5_s5.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v3_s9.pickle',
#  'results_gp_cov_police_deepar_time_warp_v1_s3.pickle',
#  'results_gp_cov_tourism_mint_scaling_v2_s8.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v1_s5.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v3_s3.pickle',
#  'results_gp_cov_tourism_mint_jitter_v2_s2.pickle',
#  'results_gp_cov_prison_mint_scaling_v2_s9.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v4_s4.pickle',
#  'results_gp_cov_prison_deepar_scaling_v3_s8.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v1_s1.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v1_s6.pickle',
#  'results_gp_cov_prison_deepar_scaling_v1_s6.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v2_s4.pickle',
#  'results_gp_cov_m5_deepar_jitter_v3_s0.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v5_s2.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v3_s0.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v3_s7.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v3_s4.pickle',
#  'results_gp_cov_prison_mint_time_warp_v5_s0.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v4_s9.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v5_s4.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v4_s1.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v3_s9.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v0_s3.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v1_s5.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v1_s5.pickle',
#  'results_gp_cov_m5_mint_jitter_orig_s0.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v3_s2.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v1_s5.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v5_s9.pickle',
#  'results_gp_cov_prison_gpf_jitter_v1_s2.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v5_s0.pickle',
#  'results_gp_cov_police_deepar_time_warp_v4_s1.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v1_s0.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v2_s7.pickle',
#  'results_gp_cov_tourism_mint_jitter_v5_s6.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v2_s5.pickle',
#  'results_gp_cov_prison_deepar_jitter_v0_s7.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v2_s9.pickle',
#  'results_gp_cov_tourism_mint_scaling_v3_s1.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v2_s0.pickle',
#  'results_gp_cov_prison_mint_jitter_v1_s7.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v0_s4.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v4_s5.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v1_s6.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v5_s4.pickle',
#  'results_gp_cov_m5_deepar_jitter_v0_s7.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v3_s7.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v0_s5.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v5_s0.pickle',
#  'results_gp_cov_prison_gpf_scaling_v0_s3.pickle',
#  'results_gp_cov_m5_mint_time_warp_v5_s4.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v1_s5.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v0_s4.pickle',
#  'results_gp_cov_m5_deepar_jitter_v4_s4.pickle',
#  'results_gp_cov_m5_deepar_scaling_v0_s4.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v2_s7.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v3_s3.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v5_s5.pickle',
#  'results_gp_cov_m5_deepar_jitter_v1_s1.pickle',
#  'results_gp_cov_m5_mint_scaling_v5_s9.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v1_s9.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v5_s4.pickle',
#  'results_gp_cov_police_deepar_jitter_v3_s9.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v0_s3.pickle',
#  'results_gp_cov_prison_deepar_jitter_v5_s6.pickle',
#  'results_gp_cov_police_mint_jitter_v2_s3.pickle',
#  'results_gp_cov_m5_mint_time_warp_v1_s2.pickle',
#  'results_gp_cov_prison_gpf_jitter_v3_s6.pickle',
#  'results_gp_cov_police_gpf_jitter_v0_s6.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v3_s4.pickle',
#  'results_gp_cov_prison_mint_time_warp_v2_s1.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v0_s3.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v5_s8.pickle',
#  'results_gp_cov_m5_deepar_jitter_v2_s9.pickle',
#  'results_gp_cov_tourism_mint_scaling_v0_s1.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v1_s1.pickle',
#  'results_gp_cov_prison_deepar_scaling_v0_s0.pickle',
#  'results_gp_cov_tourism_mint_scaling_v1_s4.pickle',
#  'results_gp_cov_tourism_mint_scaling_v4_s6.pickle',
#  'results_gp_cov_prison_gpf_jitter_v3_s8.pickle',
#  'results_gp_cov_prison_mint_time_warp_v4_s6.pickle',
#  'results_gp_cov_m5_mint_time_warp_v4_s7.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v3_s0.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v5_s7.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v0_s2.pickle',
#  'results_gp_cov_m5_mint_scaling_v5_s0.pickle',
#  'results_gp_cov_m5_mint_scaling_v3_s0.pickle',
#  'results_gp_cov_prison_gpf_scaling_v3_s4.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v0_s1.pickle',
#  'results_gp_cov_police_deepar_time_warp_v2_s9.pickle',
#  'results_gp_cov_police_mint_jitter_v1_s7.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v2_s8.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v1_s2.pickle',
#  'results_gp_cov_police_deepar_scaling_v2_s6.pickle',
#  'results_gp_cov_m5_deepar_scaling_v4_s0.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v4_s7.pickle',
#  'results_gp_cov_m5_mint_time_warp_v5_s6.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v4_s7.pickle',
#  'results_gp_cov_police_gpf_scaling_v1_s0.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v0_s1.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v0_s7.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v3_s2.pickle',
#  'results_gp_cov_police_mint_jitter_v3_s2.pickle',
#  'results_gp_cov_m5_deepar_jitter_v1_s0.pickle',
#  'results_gp_cov_m5_mint_scaling_v5_s5.pickle',
#  'results_gp_cov_m5_deepar_scaling_v5_s0.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_orig_s0.pickle',
#  'results_gp_cov_police_deepar_jitter_v4_s3.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v0_s9.pickle',
#  'results_gp_cov_prison_mint_scaling_v5_s0.pickle',
#  'results_gp_cov_m5_gpf_jitter_v5_s4.pickle',
#  'results_gp_cov_m5_mint_scaling_v1_s5.pickle',
#  'results_gp_cov_tourism_mint_scaling_v4_s5.pickle',
#  'results_gp_cov_tourism_mint_jitter_v5_s0.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v0_s6.pickle',
#  'results_gp_cov_prison_mint_scaling_v2_s3.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v2_s0.pickle',
#  'results_gp_cov_prison_mint_time_warp_v5_s8.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v2_s3.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v3_s4.pickle',
#  'results_gp_cov_police_deepar_jitter_v4_s2.pickle',
#  'results_gp_cov_m5_mint_time_warp_v1_s8.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v5_s8.pickle',
#  'results_gp_cov_prison_deepar_jitter_v3_s3.pickle',
#  'results_gp_cov_tourism_mint_jitter_v5_s5.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v0_s1.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v5_s4.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v4_s4.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v1_s0.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v0_s2.pickle',
#  'results_gp_cov_police_deepar_scaling_v0_s3.pickle',
#  'results_gp_cov_prison_deepar_scaling_v5_s0.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v0_s8.pickle',
#  'results_gp_cov_m5_deepar_scaling_v1_s8.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v5_s1.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v1_s1.pickle',
#  'results_gp_cov_prison_deepar_jitter_v5_s2.pickle',
#  'results_gp_cov_m5_deepar_jitter_v1_s3.pickle',
#  'results_gp_cov_tourism_mint_jitter_v3_s4.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v3_s9.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v2_s2.pickle',
#  'results_gp_cov_police_deepar_jitter_v3_s6.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v1_s3.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v3_s4.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v2_s6.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v5_s7.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v1_s0.pickle',
#  'results_gp_cov_m5_gpf_jitter_v1_s9.pickle',
#  'results_gp_cov_tourism_mint_scaling_v0_s2.pickle',
#  'results_gp_cov_police_deepar_time_warp_v1_s2.pickle',
#  'results_gp_cov_m5_deepar_jitter_v0_s8.pickle',
#  'results_gp_cov_m5_mint_scaling_v3_s6.pickle',
#  'results_gp_cov_prison_gpf_jitter_v0_s7.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v4_s9.pickle',
#  'results_gp_cov_police_deepar_jitter_v1_s6.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v4_s8.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v3_s1.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v3_s6.pickle',
#  'results_gp_cov_prison_mint_time_warp_v1_s3.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v4_s3.pickle',
#  'results_gp_cov_police_deepar_time_warp_v1_s4.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v5_s2.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v2_s7.pickle',
#  'results_gp_cov_m5_deepar_scaling_v3_s6.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_orig_s0.pickle',
#  'results_gp_cov_m5_mint_scaling_v0_s2.pickle',
#  'results_gp_cov_m5_mint_jitter_v5_s7.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v0_s8.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v5_s5.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v2_s8.pickle',
#  'results_gp_cov_prison_deepar_scaling_v3_s0.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v4_s8.pickle',
#  'results_gp_cov_m5_gpf_magnitude_warp_orig_s0.pickle',
#  'results_gp_cov_m5_mint_jitter_v1_s9.pickle',
#  'results_gp_cov_prison_deepar_jitter_v0_s1.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v2_s6.pickle',
#  'results_gp_cov_m5_mint_time_warp_v4_s5.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v0_s7.pickle',
#  'results_gp_cov_prison_deepar_jitter_v2_s6.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v2_s8.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v5_s7.pickle',
#  'results_gp_cov_tourism_mint_scaling_v2_s7.pickle',
#  'results_gp_cov_prison_gpf_scaling_v3_s9.pickle',
#  'results_gp_cov_tourism_mint_jitter_v3_s8.pickle',
#  'results_gp_cov_prison_deepar_scaling_v4_s8.pickle',
#  'results_gp_cov_tourism_gpf_time_warp_v2_s1.pickle',
#  'results_gp_cov_m5_deepar_jitter_v0_s0.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v0_s7.pickle',
#  'results_gp_cov_prison_mint_scaling_v3_s8.pickle',
#  'results_gp_cov_prison_gpf_jitter_v5_s4.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v5_s1.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v3_s4.pickle',
#  'results_gp_cov_m5_mint_time_warp_v1_s6.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v0_s6.pickle',
#  'results_gp_cov_prison_gpf_scaling_v4_s4.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v0_s8.pickle',
#  'results_gp_cov_prison_deepar_jitter_v0_s5.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v5_s9.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v5_s9.pickle',
#  'results_gp_cov_m5_mint_jitter_v2_s7.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v0_s3.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v2_s4.pickle',
#  'results_gp_cov_m5_mint_scaling_v5_s4.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v5_s4.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v1_s7.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v2_s8.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v2_s1.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v0_s7.pickle',
#  'results_gp_cov_prison_mint_scaling_v5_s4.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v0_s5.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v2_s3.pickle',
#  'results_gp_cov_police_deepar_scaling_v1_s7.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v3_s1.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v0_s9.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v2_s9.pickle',
#  'results_gp_cov_prison_gpf_scaling_v0_s8.pickle',
#  'results_gp_cov_m5_mint_scaling_orig_s0.pickle',
#  'results_gp_cov_m5_gpf_jitter_v3_s0.pickle',
#  'results_gp_cov_police_deepar_scaling_v0_s6.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v4_s0.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v3_s5.pickle',
#  'results_gp_cov_m5_mint_time_warp_v5_s2.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v3_s5.pickle',
#  'results_gp_cov_prison_mint_time_warp_v2_s5.pickle',
#  'results_gp_cov_prison_gpf_scaling_v5_s4.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v4_s7.pickle',
#  'results_gp_cov_prison_gpf_scaling_v4_s7.pickle',
#  'results_gp_cov_police_deepar_jitter_v4_s4.pickle',
#  'results_gp_cov_prison_mint_jitter_v4_s2.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v2_s0.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v4_s0.pickle',
#  'results_gp_cov_m5_mint_jitter_v3_s2.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v5_s1.pickle',
#  'results_gp_cov_tourism_mint_scaling_v5_s9.pickle',
#  'results_gp_cov_m5_mint_scaling_v2_s3.pickle',
#  'results_gp_cov_tourism_gpf_time_warp_v1_s2.pickle',
#  'results_gp_cov_police_deepar_jitter_v2_s3.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v1_s3.pickle',
#  'results_gp_cov_tourism_gpf_time_warp_v0_s8.pickle',
#  'results_gp_cov_m5_deepar_scaling_v5_s1.pickle',
#  'results_gp_cov_m5_mint_jitter_v4_s1.pickle',
#  'results_gp_cov_m5_mint_jitter_v1_s8.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v2_s0.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v4_s1.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v5_s9.pickle',
#  'results_gp_cov_m5_deepar_jitter_v5_s0.pickle',
#  'results_gp_cov_prison_deepar_time_warp_orig_s0.pickle',
#  'results_gp_cov_prison_mint_jitter_v2_s8.pickle',
#  'results_gp_cov_tourism_gpf_time_warp_v2_s2.pickle',
#  'results_gp_cov_police_deepar_jitter_v3_s1.pickle',
#  'results_gp_cov_m5_deepar_scaling_v4_s4.pickle',
#  'results_gp_cov_tourism_mint_scaling_v5_s3.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v3_s8.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v0_s2.pickle',
#  'results_gp_cov_police_deepar_jitter_v0_s2.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v0_s6.pickle',
#  'results_gp_cov_m5_gpf_jitter_v5_s1.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v3_s5.pickle',
#  'results_gp_cov_prison_deepar_scaling_v1_s2.pickle',
#  'results_gp_cov_prison_mint_time_warp_v5_s5.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v5_s1.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v4_s5.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v4_s0.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v4_s7.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v5_s1.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v1_s0.pickle',
#  'results_gp_cov_police_deepar_scaling_v4_s1.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v3_s5.pickle',
#  'results_gp_cov_police_gpf_scaling_v0_s1.pickle',
#  'results_gp_cov_m5_mint_scaling_v1_s0.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v3_s9.pickle',
#  'results_gp_cov_m5_deepar_scaling_v4_s5.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v5_s1.pickle',
#  'results_gp_cov_police_deepar_jitter_v4_s9.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v4_s5.pickle',
#  'results_gp_cov_m5_mint_time_warp_v0_s1.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v5_s2.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v1_s6.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v5_s3.pickle',
#  'results_gp_cov_tourism_gpf_scaling_orig_s0.pickle',
#  'results_gp_cov_tourism_gpf_time_warp_v1_s6.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v4_s8.pickle',
#  'results_gp_cov_m5_deepar_jitter_v2_s7.pickle',
#  'results_gp_cov_m5_mint_time_warp_v4_s3.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v1_s2.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v3_s3.pickle',
#  'results_gp_cov_prison_mint_scaling_v5_s7.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v0_s1.pickle',
#  'results_gp_cov_m5_mint_jitter_v0_s0.pickle',
#  'results_gp_cov_police_gpf_scaling_orig_s0.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v4_s3.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v0_s6.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v0_s4.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v1_s8.pickle',
#  'results_gp_cov_prison_mint_scaling_v3_s7.pickle',
#  'results_gp_cov_m5_deepar_scaling_v2_s2.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v4_s2.pickle',
#  'results_gp_cov_police_deepar_time_warp_v3_s1.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v4_s7.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v4_s4.pickle',
#  'results_gp_cov_m5_deepar_scaling_v5_s9.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v1_s4.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v0_s0.pickle',
#  'results_gp_cov_tourism_gpf_scaling_v1_s2.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v2_s8.pickle',
#  'results_gp_cov_m5_deepar_scaling_v0_s1.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v2_s2.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v3_s7.pickle',
#  'results_gp_cov_m5_mint_scaling_v2_s5.pickle',
#  'results_gp_cov_prison_gpf_scaling_v4_s5.pickle',
#  'results_gp_cov_police_deepar_time_warp_v5_s9.pickle',
#  'results_gp_cov_tourism_mint_scaling_v1_s3.pickle',
#  'results_gp_cov_m5_deepar_jitter_v2_s8.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v5_s3.pickle',
#  'results_gp_cov_m5_mint_scaling_v5_s7.pickle',
#  'results_gp_cov_police_deepar_time_warp_v5_s6.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v2_s1.pickle',
#  'results_gp_cov_prison_mint_jitter_v1_s3.pickle',
#  'results_gp_cov_tourism_mint_scaling_v1_s0.pickle',
#  'results_gp_cov_prison_gpf_scaling_v1_s8.pickle',
#  'results_gp_cov_m5_mint_time_warp_v3_s8.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v3_s9.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v2_s1.pickle',
#  'results_gp_cov_tourism_mint_jitter_v2_s4.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v0_s2.pickle',
#  'results_gp_cov_prison_gpf_time_warp_v4_s7.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v4_s1.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v3_s6.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v1_s0.pickle',
#  'results_gp_cov_m5_deepar_jitter_v2_s5.pickle',
#  'results_gp_cov_tourism_mint_jitter_v5_s2.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v1_s1.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v2_s7.pickle',
#  'results_gp_cov_tourism_mint_jitter_v4_s6.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v5_s2.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v3_s0.pickle',
#  'results_gp_cov_prison_mint_jitter_v0_s1.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v2_s8.pickle',
#  'results_gp_cov_police_deepar_time_warp_v3_s5.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v3_s0.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v5_s6.pickle',
#  'results_gp_cov_prison_mint_time_warp_v0_s7.pickle',
#  'results_gp_cov_m5_deepar_time_warp_v4_s3.pickle',
#  'results_gp_cov_prison_deepar_jitter_v5_s5.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v2_s6.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v2_s7.pickle',
#  'results_gp_cov_prison_mint_jitter_v0_s8.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v1_s3.pickle',
#  'results_gp_cov_police_deepar_time_warp_v4_s8.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v0_s5.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v5_s5.pickle',
#  'results_gp_cov_prison_deepar_jitter_v0_s3.pickle',
#  'results_gp_cov_m5_gpf_jitter_v0_s8.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v2_s4.pickle',
#  'results_gp_cov_prison_gpf_jitter_v2_s4.pickle',
#  'results_gp_cov_tourism_mint_time_warp_v4_s4.pickle',
#  'results_gp_cov_prison_mint_jitter_v0_s2.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v5_s8.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v3_s1.pickle',
#  'results_gp_cov_prison_mint_magnitude_warp_v2_s4.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v2_s7.pickle',
#  'results_gp_cov_prison_deepar_magnitude_warp_v4_s3.pickle',
#  'results_gp_cov_tourism_mint_scaling_v0_s3.pickle',
#  'results_gp_cov_tourism_deepar_jitter_v2_s3.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v2_s4.pickle',
#  'results_gp_cov_m5_mint_jitter_v1_s3.pickle',
#  'results_gp_cov_tourism_gpf_magnitude_warp_v1_s6.pickle',
#  'results_gp_cov_tourism_deepar_magnitude_warp_v4_s9.pickle',
#  'results_gp_cov_m5_deepar_scaling_v2_s7.pickle',
#  'results_gp_cov_prison_gpf_scaling_v5_s5.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v2_s6.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v3_s0.pickle',
#  'results_gp_cov_m5_mint_scaling_v0_s4.pickle',
#  'results_gp_cov_m5_mint_jitter_v3_s0.pickle',
#  'results_gp_cov_prison_deepar_jitter_v5_s1.pickle',
#  'results_gp_cov_prison_mint_scaling_v0_s4.pickle',
#  'results_gp_cov_prison_gpf_jitter_v4_s8.pickle',
#  'results_gp_cov_prison_gpf_scaling_v3_s2.pickle',
#  'results_gp_cov_police_deepar_magnitude_warp_v3_s8.pickle',
#  'results_gp_cov_prison_mint_time_warp_v5_s7.pickle',
#  'results_gp_cov_prison_gpf_jitter_v0_s1.pickle',
#  'results_gp_cov_police_gpf_scaling_v1_s3.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v2_s1.pickle',
#  'results_gp_cov_prison_mint_time_warp_v0_s6.pickle',
#  'results_gp_cov_m5_mint_magnitude_warp_v1_s9.pickle',
#  'results_gp_cov_tourism_mint_magnitude_warp_v0_s7.pickle',
#  'results_gp_cov_prison_gpf_magnitude_warp_v3_s1.pickle',
#  'results_gp_cov_prison_deepar_jitter_v0_s6.pickle',
#  'results_gp_cov_m5_deepar_magnitude_warp_v5_s0.pickle',
#  'results_gp_cov_police_deepar_time_warp_v4_s5.pickle',
#  'results_gp_cov_police_deepar_scaling_v5_s9.pickle',
#  'results_gp_cov_prison_gpf_scaling_v2_s6.pickle',
#  'results_gp_cov_tourism_deepar_scaling_v4_s2.pickle',
#  'results_gp_cov_prison_deepar_time_warp_v1_s7.pickle',
#  'results_gp_cov_prison_gpf_scaling_v5_s6.pickle',
#  'results_gp_cov_tourism_gpf_jitter_v3_s6.pickle',
#  'results_gp_cov_m5_mint_time_warp_v2_s6.pickle',
#  'results_gp_cov_tourism_deepar_time_warp_v1_s8.pickle',
#  ...]

# %%
def compute_aggreated_results(algorithm, dataset, path='../results', err_metric='mase'):
    results_dict={}
    for file in [path for path in os.listdir(path) if algorithm in path and dataset in path]:
        with open(f'{path}/{file}', 'rb') as handle:
            flatten_file_name = list(flatten([i.split('.') for i in file.split('_')]))
            idx_dataset_name = find(flatten_file_name, dataset)[0]
            sample = flatten_file_name[idx_dataset_name+1:-1][-1]
            version = flatten_file_name[idx_dataset_name+1:-1][-2]
            transformation = '_'.join(flatten_file_name[idx_dataset_name+1:-1][:-2])
            if not keys_exists(results_dict, transformation):
                results_dict[transformation] = {}
            if not keys_exists(results_dict, transformation, version): 
                results_dict[transformation][version] = {}
            if not keys_exists(results_dict, transformation, version, sample):    
                results_dict[transformation][version][sample] = {}

            results_dict[transformation][version][sample] = pickle.load(handle)
        handle.close()

    # shape=(transformation, version, sample, metric, dim)
    # metric = mase, rmse
    # dim = bottom, total, state, gender, legal, all

    df = pd.DataFrame.from_dict({(i,j, k, l): results_dict[i][j][k][l] 
                               for i in results_dict.keys() 
                               for j in results_dict[i].keys()
                               for k in results_dict[i][j].keys()
                               for l in results_dict[i][j][k].keys()},
                           orient='index')

    df_err = df[np.in1d(df.index.get_level_values(3), [err_metric])]
    df_clean = df_err.mean(level=(0,1,2)).stack(level=0).to_frame()
    df_clean = df_clean.reset_index()
    df_clean.columns = ['transformation', 'version', 'sample', 'group', err_metric]
    
    # Calculate percentage change
    df = df_clean.copy()
    s = df.set_index(['transformation', 'version', 'sample', 'group'])[err_metric].unstack('version')
    df = df.set_index(['transformation', 'version', 'sample', 'group'])
    df_pct = pd.DataFrame(s.div(s['orig'].groupby(['transformation', 'group']).transform(lambda x: x.fillna(x.sum())), axis='rows').sub(1).stack()).reset_index().set_index(['transformation', 'version', 'sample', 'group'])
    df_pct = df_pct.rename(columns={0: 'pct_change'})
    df_updated = df.merge(df_pct, how='left', left_index=True, right_index=True)
    
    # Calculate relative change
    df = df_clean.copy()
    s = df.set_index(['transformation', 'version', 'sample', 'group'])[err_metric].unstack('version')
    df = df.set_index(['transformation', 'version', 'sample', 'group'])
    df_rel = pd.DataFrame(s.sub(s['orig']
                                .groupby(['transformation', 'group'])
                                .transform(lambda x: x.fillna(x.sum())), axis='rows')
                          .stack()).reset_index().set_index(['transformation', 'version', 'sample', 'group'])
    df_rel = df_rel.rename(columns={0: 'rel_change'})
    df_new = df_updated.merge(df_rel, how='left', left_index=True, right_index=True)
    df_new = df_new.reset_index()
    
    return df_new

def plot_results(df, err_metric='mase'):
    _, ax = plt.subplots(2, 2, figsize=(20, 20))
    ax = ax.ravel()
    transf = df.transformation.unique()
    transf.sort()
    for i in range(len(transf)):
        fg = sns.lineplot(x='version', y=err_metric, hue='group', marker='o', data=df.loc[df['transformation']==transf[i]].sort_values(['version', 'group']), ax=ax[i])
        ax[i].set_ylim(0, 6.0)
        ax[i].set_title(transf[i], fontsize=22)
        
def plot_results_perc_diff(df):
    _, ax = plt.subplots(2, 2, figsize=(20, 20))
    ax = ax.ravel()
    transf = df.transformation.unique()
    transf.sort()
    for i in range(len(transf)):
        fg = sns.lineplot(x='version', 
                          y='pct_change', 
                          hue='group', 
                          marker='o', 
                          data=df.loc[df['transformation']==transf[i]].sort_values(['version', 'group']), 
                          ax=ax[i])
        ax[i].set_ylim(-0.5, 2.5)
        ax[i].set_title(transf[i], fontsize=22)
        
def plot_results_joint(df1, df2, df3, err_metric='mase'):
    
    if err_metric=='mase':
        ylim=(0, 6)
    elif err_metric=='rmse':
        ylim=(0, 6000)
    elif err_metric=='pct_change':
        ylim=(-0.5, 2.5)
    elif err_metric=='rel_change':
        ylim=(-1, 3.5)
        
    _, ax = plt.subplots(4, 3, figsize=(40, 20))
    transf = df1.transformation.unique()
    transf.sort()
    for i in range(len(transf)):
        fg = sns.lineplot(x='version', 
                          y=err_metric, 
                          hue='group', 
                          marker='o', 
                          data=df1.loc[df1['transformation']==transf[i]].sort_values(['version', 'group']), 
                          ax=ax[i, 0])
        ax[i,0].set_ylim(*ylim)
        ax[i,0].set_title(transf[i], fontsize=22)

    transf = df2.transformation.unique()
    transf.sort()
    for i in range(len(transf)):

        fg = sns.lineplot(x='version', 
                          y=err_metric, 
                          hue='group', 
                          marker='o', 
                          data=df2.loc[df2['transformation']==transf[i]].sort_values(['version', 'group']), 
                          ax=ax[i,1])        
        ax[i,1].set_ylim(*ylim)
        ax[i,1].set_title(transf[i], fontsize=22)
    
    transf = df3.transformation.unique()
    transf.sort()  
    for i in range(len(transf)):
        fg = sns.lineplot(x='version', 
                          y=err_metric, 
                          hue='group', 
                          marker='o', 
                          data=df3.loc[df3['transformation']==transf[i]].sort_values(['version', 'group']), 
                          ax=ax[i,2])        
        ax[i,2].set_ylim(*ylim)
        ax[i,2].set_title(transf[i], fontsize=22)
        
    plt.tight_layout()

# %%
df_gpf_mase = compute_aggreated_results(algorithm='gpf', dataset=dataset)
df_mint_mase = compute_aggreated_results(algorithm='mint', dataset=dataset)
df_deepar_mase = compute_aggreated_results(algorithm='deepar', dataset=dataset)

# %%
df_gpf_rmse = compute_aggreated_results(algorithm='gpf', dataset=dataset, err_metric='rmse')
df_mint_rmse = compute_aggreated_results(algorithm='mint', dataset=dataset, err_metric='rmse')
df_deepar_rmse = compute_aggreated_results(algorithm='deepar', dataset=dataset, err_metric='rmse')

# %%
plot_results_joint(df_gpf_rmse, df_mint_rmse, df_deepar_rmse, 'rmse')

# %%
plot_results_joint(df_gpf_rmse, df_mint_rmse, df_deepar_rmse, 'pct_change')
